# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # Ejercicios Python Basics II

# %% [markdown]
# ## Ejercicio 1
# * Crea dos variables numericas: un `int` y un `float`
# * Comprueba sus tipos
# * Sumalas en otra nueva
# * ¿De qué tipo es la nueva variable?
# * Elimina las dos primeras variables creadas

# %%
numero_entero = 17
numero_real = 1.7

print(type(numero_entero))
print(type(numero_real))

suma_real_entero = numero_entero + numero_real
print(suma_real_entero)

print (type(suma_real_entero))

del(numero_entero)
del(numero_real)

comprobacion = numero_real - numero_entero
print(comprobacion)
# Out:
# <class 'int'>
# <class 'float'>
# 18.7
# <class 'float'>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 15
#      11
#      12 del(numero_entero)
#      13 del(numero_real)
#      14
# ---> 15 comprobacion = numero_real - numero_entero
#      16 print(comprobacion)
#
# NameError: name 'numero_real' is not defined

# %% [markdown]
# ## Ejercicio 2
# Escribe un programa para pasar de grados a radianes. Hay que usar `input`. Recuerda que la conversión se realiza mediante
#
# radianes = grados*(pi/180)

# %%
import math

grados = float(input("¿Cuántos grados quieres pasar a radianes?"))

radianes = grados * (math.pi /180)

print ("%s grados equivalen a %s radianes" % (grados, radianes) )
# Out:
# 125.0 grados equivalen a 2.181661564992912 radianes

# %% [markdown]
# ## Ejercicio 3
# Escribe un programa que calcule el area de un paralelogramo (base x altura). También con `input`

# %%
base = float(input("¿Cuánto mide la base de tu paralelogramo?"))
altura = float(input("¿Cuánto mide la altura de tu paralelogramo?"))

area = altura * base

print ("El area de tu paralelogramo es %s" % (area) )
# Out:
# El area de tu paralelogramo es 100.0

# %% [markdown]
# ## Ejercicio 4
# Tenemos las siguientes variables:
#
# ```Python
# A = 4
# B = "Text"
# C = 4.1
# ```
#
# Comprueba:
# 1. Si A y B son equivalentes
# 2. Si A y C NO son equivalentes
# 3. Si A es mayor que C
# 4. Si C es menor o igual que A
# 5. Si B NO es equivalente a C

# %%
A = 4
B = "Text"
C = 4.1

print(A==B)
print(A!=C)
print(A>=C)
print(C<=A)
print(B!=C)
# Out:
# False
# True
# False
# False
# True

# %% [markdown]
# ## Ejercicio 5
# Crea un programa donde se recojan dos inputs del usuario, y el output del programa sea si esos inputs son iguales o no

# %%
edad_madre = input("¿Cuántos años tiene tu madre?")
edad_padre = input("¿Cuántos años tiene tu padre?")

print (edad_madre == edad_padre)
# Out:
# False

# %% [markdown]
# ## Ejercicio 6
# Mismo programa que en 5, pero en esta ocasión tienen que ser tres inputs y dos salidas. Una de las salidas que nos indique si todos son iguales, y la otra si al menos dos inputs sí que lo son

# %%
edad_madre = input("¿Cuántos años tiene tu madre?")
edad_padre = input("¿Cuántos años tiene tu padre?")
edad_tia = input("¿Cuántos años tiene tu tía?")

print (edad_madre == edad_padre == edad_tia)
print (edad_tia == edad_padre or edad_tia == edad_madre or edad_padre == edad_madre)
# Out:
# False
# True

# %% [markdown]
# ## Ejercicio 7
# Crea un programa que recoja dos inputs. Tiene que comprobar si su suma es igual, superior o inferior a 10

# %%
nota_practica = float(input("¿Cuál es tu nota de prácticas?"))
nota_examen = float(input("¿Cuál es tu nota del examen?"))
suma = nota_examen + nota_practica

print(f"La nota es inferior a 10: {suma < 10}")
print(f"La nota es superior a 10: {suma > 10}")
print(f"La nota es igual a 10: {suma == 10}")
# Out:
# La nota es inferior a 10: False
# La nota es superior a 10: True
# La nota es igual a 10: False

# %%
nota_practica = float(input("¿Cuál es tu nota de prácticas?"))
nota_examen = float(input("¿Cuál es tu nota del examen?"))
suma = nota_examen + nota_practica

if suma < 10:
    print(f"La nota es inferior a 10 (Total: {suma})")

elif suma > 10:
    print(f"La nota es superior a 10 (Total: {suma})")

else:
    print(f"La nota es igual a 10 (Total: {suma})")
# Out:
# La nota es igual a 10 (Total: 10.0)

# %% [markdown]
# ## Ejercicio 8
# Razona sin ejecutar código el output que obtendremos de las siguientes sentencias
# 1. True and True and False
# 2. not ((True or False) and (True or False))
# 3. (False or False or False or True) and False
# 4. not False and True and not True

# %% [markdown]
# 1. False
# 2. True
# 3. True
# 4. False

# %% [markdown]
# ## Ejercicio 9
# Para este ejercicio vamos a poner en práctica [las funciones built in](https://docs.python.org/3/library/functions.html).
#
# 1. Calcula el máximo de la lista: [4, 6, 8, -1]
# 2. Suma todos los elementos de la lista anterior
# 3. Redondea este float a 3 dígitos decimales: 63.451256965
# 4. Valor absoluto de: -74

# %%
lista9 = [4,6,8,-1]
print(sum(lista9))
num9 = 63.451256965
print(round(num9, 3))
abs(-74)
# Out:
# 17
# 63.451
# 74

# %% [markdown]
# ## Ejercicio 10
# Para el siguiente string se pide imprimir por pantalla los siguientes casos
#
#     "En un lugar de la Mancha, de cuyo nombre no quiero acordarme."
#
# 1. Pásalo todo a mayúsculas
# 2. Pásalo todo a minúsculas
# 3. Solo la primera letra de cada palabra en mayúscula, el resto en minúscula
# 4. Crea una lista dividiéndolo por sus espacios
# 5. Sustituye las comas `,` por puntos y comas `;`
# 6. Elimina las `a` minúsculas

# %%
quijote = "En un lugar de la Mancha, de cuyo nombre no quiero acordarme."

print(quijote.upper())

print(quijote.lower())

print(quijote.title())

print(quijote.split(" "))

print(quijote.replace(",", ";"))

print(quijote.replace("a", ""))
# Out:
# EN UN LUGAR DE LA MANCHA, DE CUYO NOMBRE NO QUIERO ACORDARME.
# en un lugar de la mancha, de cuyo nombre no quiero acordarme.
# En Un Lugar De La Mancha, De Cuyo Nombre No Quiero Acordarme.
# ['En', 'un', 'lugar', 'de', 'la', 'Mancha,', 'de', 'cuyo', 'nombre', 'no', 'quiero', 'acordarme.']
# En un lugar de la Mancha; de cuyo nombre no quiero acordarme.
# En un lugr de l Mnch, de cuyo nombre no quiero cordrme.

# %% [markdown]
# ## Ejercicio 11
# 1. Crea una lista con 3 elementos numéricos
# 2. Añade un cuarto elemento
# 3. Calcula la suma de todos
# 4. Elimina el segundo elemento de la lista
# 5. Añade otro elemento en la posicion 3 de la lista
# 6. Crea otra lista con 4 elementos y concaténala a la que ya tenías.

# %%
lista11 = [17,2001,4.9]
print(lista11)
lista11.append(432)
print(lista11)
print(sum(lista11))
del lista11[1]
print(lista11)

lista12 = [67, 77.3, 92, 101]
lista_sum = lista11 + lista12
print(lista_sum)
# Out:
# [17, 2001, 4.9]
# [17, 2001, 4.9, 432]
# 2454.9
# [17, 4.9, 432]
# [17, 4.9, 432, 67, 77.3, 92, 101]
