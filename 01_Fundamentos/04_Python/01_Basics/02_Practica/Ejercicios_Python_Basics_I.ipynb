# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # Ejercicios Python Basics I

# %% [markdown]
# ## Ejercicio 1
# Imprime por pantalla esta cita con el siguiente formato
#
# ![imagen](./img/frase_Einstein.PNG)

# %%
print("Por qué esta magnífica tecnología científica,\n\tque ahorra trabajo y nos hace la vida mas fácil,\n\t\tnos aporta tan poca felicidad?\n\t\t\tLa repuesta es está, simplemente: porque aún no hemos aprendido a usarla con tino.")
print("''Albert Einstein''")
# Out:
# Por qué esta magnífica tecnología científica,
# 	que ahorra trabajo y nos hace la vida mas fácil,
# 		nos aporta tan poca felicidad?
# 			La repuesta es está, simplemente: porque aún no hemos aprendido a usarla con tino.
# ''Albert Einstein''

# %% [markdown]
# ## Ejercicio 2
# 1. Escribe el nombre de la calle de tu domicilio
# 2. Escribe el numero de la calle en otra
# 3. Población en una tercera
# 4. Codigo postal en la cuarta variable
# 5. Crea una quinta variable que concatene todas ellas
# 6. Imprimela por pantalla

# %%
nombre_calle = "Carrer Molinell "
numero_calle = "Nº 17 "
poblacion = "València "
cp = "46010"
domicilio = nombre_calle + numero_calle + poblacion + cp
print(domicilio)
# Out:
# Carrer Molinell Nº 17 València 46010

# %% [markdown]
# ## Ejercicio 3
# Replica el output del ejercicio dos, pero está vez sin usar una variable intermedia que concatene todas las demas. Realiza este ejercicio en una línea, con un  único `print`

# %%
print(f"{nombre_calle}{numero_calle}{poblacion}{cp}")
# Out:
# Carrer Molinell Nº 17 València 46010

# %% [markdown]
# ## Ejercicio 4
# ¿Qué variables están mal escritas y por qué? Realiza primero tu hipótesis y luego ejecuta las variables para comprobarlo. En ese orden :)
#
#
# 1. mi_variable = "Economía"
# 2. otra_var = "Ejercicio
# 3. True = "Ejercicio"
# 4. mi variab1e = "Alpha"
# 5. exec = True
# 6. import = 40
# 7. 81mi_variable = "Agua"
# 8. mi_variable10 = 6

# %% [markdown]
# 1. Está bien escrita
# 2. Le falta cerrar comillas. otra_var = "Ejercicio"
# 3. No puedes utilizar True porque forma parte del diccionario de Python
# 4. No puede haber espacios. Mi_variab1e = "Alpha"
# 5. Está bien escrita
# 6. No puedes utilizar Import porque es una palabra clave reservada de Python
# 7. No puedes crear variables en Python cuyo nombre empiece con un número
# 8. Está bien escrita

# %% [markdown]
# ## Ejercicio 5
# Realiza un conversor de grados Celsius a Fahrenheit. El conversor tiene que recibir el input del usuario y devolver la conversión.
#
# La conversión de grados sigue la siguiente fórmula: F = (C × 9 / 5) + 32

# %%
grados_celsius = float(input("¿Qué temperatura hace en grados Celsius?"))

grados_fahrenheit = grados_celsius * (9 / 5) + 32

print("El equivalente en grados Fahrenheit es %sFº" % (grados_fahrenheit))
# Out:
# El equivalente en grados Fahrenheit es 93.2Fº

# %% [markdown]
# ## Ejercicio 6
# Comenta en la medida de lo posible el Ejercicio 5. Será suficiente con poner al menos un comentario de línea, y otro multilínea

# %%
# He aprendido a crear asistentes virtuales

"""
Son muy útiles para solucionar  del día a día
"""
# Out:
# '\nSon muy útiles para solucionar  del día a día\n'
